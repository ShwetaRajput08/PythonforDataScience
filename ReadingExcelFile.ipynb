# %% [markdown]
# # Reading an excel file and Image file in Python

# %% [markdown]
# Command to install xlrd module :

# %% [markdown]
# pip install xlrd

# %% [markdown]
# ![installXlrd.png](attachment:installXlrd.png)

# %%
import xlrd

# %%
location = ("color.xlsx")

# %% [markdown]
# ![color.png](attachment:color.png)

# %%
xfp = xlrd.open_workbook(location) 
sheet = xfp.sheet_by_index(0) 
print(sheet.cell_value(0, 0))
# Out:
# color

# %% [markdown]
# To get no of rows

# %%
print(sheet.nrows)
# Out:
# 7

# %% [markdown]
# To get no of col

# %%
print(sheet.ncols)
# Out:
# 2

# %%
for i in range(sheet.ncols): 
    print(sheet.cell_value(0, i))
# Out:
# color
# no

# %% [markdown]
# Reading a particular row

# %%
print(sheet.row_values(0)) 
print(sheet.row_values(1)) 
print(sheet.row_values(2)) 
#print(sheet.row_value(9))
# Out:
# ['color', 'no']
# ['White', 14.0]
# ['Black', 2.0]

# %% [markdown]
# Reading file line by line

# %%
for i in range(sheet.nrows): 
    print(sheet.row_values(i))
# Out:
# ['color', 'no']
# ['White', 14.0]
# ['Black', 2.0]
# ['Pink', 5.0]
# ['Yellow', 10.0]
# ['Blue', 3.0]
# ['Red', 2.0]

# %% [markdown]
# Not Required right now

# %%
import os
if os.path.exists("demofile.txt"):
    os.remove("demofile.txt")
else:
    print("The file does not exist")
# Out:
# The file does not exist

# %% [markdown]
# Reading Image file

# %% [markdown]
# Install open cv using
# pip install opencv-python

# %% [markdown]
# ![installOpenCV.png](attachment:installOpenCV.png)

# %%
readFile=open("pluto.jpg",'rb')
readCont=readFile.readlines()
wf=open("copyPluto.jpg",'wb')
wf.write(readCont)
wf.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-da61228e986a> in <module>
#       2 readCont=readFile.readlines()
#       3 wf=open("copyPluto.jpg",'wb')
# ----> 4 wf.write(readCont)
#       5 wf.close()
#
# TypeError: a bytes-like object is required, not 'list'

# %% [markdown]
# We need to install Open CV

# %%
import cv2 
img = cv2.imread('pluto.jpg')  
cv2.imshow('image', img)  
cv2.waitKey(0)     
cv2.destroyAllWindows()

# %% [markdown]
# ![opImage.png](attachment:opImage.png)
